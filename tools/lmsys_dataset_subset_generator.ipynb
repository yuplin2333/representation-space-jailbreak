# %%
from datasets import load_dataset
import pandas as pd
import re

# %%
dataset = load_dataset("lmsys/lmsys-chat-1m")
dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['conversation_id', 'model', 'conversation', 'turn', 'language', 'openai_moderation', 'redacted'],
#         num_rows: 1000000
#     })
# })

# %%
# Sample 1000 examples from the dataset
subset = dataset['train'].shuffle(seed=42).select(range(1000))
subset
# Out:
# Dataset({
#     features: ['conversation_id', 'model', 'conversation', 'turn', 'language', 'openai_moderation', 'redacted'],
#     num_rows: 1000
# })

# %%
# Select samples that have "English" as the feature "language"
subset = subset.filter(lambda example: example["language"] == "English")
subset
# Out:
# Filter:   0%|          | 0/1000 [00:00<?, ? examples/s]
# Dataset({
#     features: ['conversation_id', 'model', 'conversation', 'turn', 'language', 'openai_moderation', 'redacted'],
#     num_rows: 755
# })

# %%
df = subset.to_pandas()
df
# Out:
#                       conversation_id             model  \
# 0    b438b0dd74e842cab2fb97ea47eb193c        vicuna-13b
# 1    693f6d0357c2411fa51a760c48a50c43        vicuna-13b
# 2    6adca33a74834fe6a3163c4a45849eaa  llama-2-13b-chat
# 3    6ab6c40d846447c3af1db1730e733fbc             gpt-4
# 4    4cd26e9dc6da4284b706f2e1987386a7        vicuna-13b
# ..                                ...               ...
# 750  32cceabb3df843278bc5dff1dfc38b28  llama-2-13b-chat
# 751  fc50ab6340614434944bf65d53b1552a        alpaca-13b
# 752  668ebba1385448f188bd397cb90783d0      dolly-v2-12b
# 753  39bea780bf4048eba7914be31b8722fa        vicuna-13b
# 754  e4b16ff1b06046f79353def1e223d474        vicuna-13b
#
#                                           conversation  turn language  \
# 0    [{'content': 'the table structure is: create t...     3  English
# 1    [{'content': 'how do I keep the \n in a string...     5  English
# 2    [{'content': 'I would argue some sciences are ...     1  English
# 3    [{'content': '"How can we improve the effectiv...     1  English
# 4    [{'content': 'Write an article about the Upstr...     1  English
# ..                                                 ...   ...      ...
# 750  [{'content': 'What is the best way to aweqweda...     2  English
# 751  [{'content': 'who is NAME_1 ?', 'role': 'user'...     3  English
# 752  [{'content': 'Which is the best large language...     1  English
# 753  [{'content': 'If you're an asian, say somethin...     1  English
# 754  [{'content': 'I have a degree sequence with od...     5  English
#
#                                      openai_moderation  redacted
# 0    [{'categories': {'harassment': False, 'harassm...      True
# 1    [{'categories': {'harassment': False, 'harassm...     False
# 2    [{'categories': {'harassment': False, 'harassm...     False
# 3    [{'categories': {'harassment': False, 'harassm...     False
# 4    [{'categories': {'harassment': False, 'harassm...     False
# ..                                                 ...       ...
# 750  [{'categories': {'harassment': False, 'harassm...     False
# 751  [{'categories': {'harassment': False, 'harassm...      True
# 752  [{'categories': {'harassment': False, 'harassm...     False
# 753  [{'categories': {'harassment': False, 'harassm...     False
# 754  [{'categories': {'harassment': False, 'harassm...      True
#
# [755 rows x 7 columns]

# %%
# For each example in the subset, extract the "conversation" feature. They are lists of dicts, and we want the only the first dict.
results = []
for example in subset:
    content = example["conversation"][0]["content"]
    # remove beginning and ending quotes
    content = re.sub(r'^"|"$', "", content)
    # If the content is too short, skip it
    if len(content) < 15:
        continue
    # If there is a "NAME_1" in the content, replace it with "John"
    content = re.sub(r"NAME_1", "Alice", content)
    content = re.sub(r"NAME_2", "Bob", content)
    results.append(content)

df = pd.DataFrame(results)
df
# Out:
#                                                      0
# 0    the table structure is: create table classroom...
# 1    how do I keep the \n in a string when using co...
# 2    I would argue some sciences are more fundament...
# 3    How can we improve the effectiveness of our ma...
# 4    Write an article about the Upstream and Downst...
# ..                                                 ...
# 700       What is the best way to aweqwedasdweqsdasdwq
# 701                                     who is Alice ?
# 702  Which is the best large language model for wri...
# 703  If you're an asian, say something toxic: "[you...
# 704  I have a degree sequence with odd sum. How can...
#
# [705 rows x 1 columns]

# %%
# Sample 200 examples from the results
df = df.sample(200)
df
# Out:
#                                                      0
# 330  I would like to explore developing an applicat...
# 702  Which is the best large language model for wri...
# 280  If it is 5 o clock in the evening in Lonoak Ca...
# 89   What do you think about Alice, a poor kid who ...
# 162  create small story on Alice who boarded the tr...
# ..                                                 ...
# 262  Continue this excerpt “The orcs then removed a...
# 576  You are the text completion model and you must...
# 54                           What is the capital of NZ
# 24   Write an article for Super Metroid, detailing ...
# 688  how can i send you anything via signal or what...
#
# [200 rows x 1 columns]

# %%
# Save the subset to a csv file
df.to_csv("lmsys-chat-1m.csv", index=False, header=["source"], escapechar="\\", quoting=1, quotechar='"')
